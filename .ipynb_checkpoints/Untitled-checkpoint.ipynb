# %%
import pandas as pd

# %%
opsd_daily = pd.read_csv('opsd_germany_daily.csv')
opsd_daily.shape
# Out:
# (4383, 5)

# %%
opsd_daily.head(3)
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN

# %%
#convert Object to datetime64[ns]
opsd_daily['Date'] = opsd_daily['Date'].values.astype('datetime64[D]')
opsd_daily.dtypes
# Out:
# Date           datetime64[ns]
# Consumption           float64
# Wind                  float64
# Solar                 float64
# Wind+Solar            float64
# dtype: object

# %%
# Make date the index
opsd_daily = opsd_daily.set_index('Date')

# %%
opsd_daily.head(3)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN

# %%
opsd_daily.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %%
# Add columns with year, month, and weekday name
opsd_daily['Year'] = opsd_daily.index.year
opsd_daily['Month'] = opsd_daily.index.month
opsd_daily['Weekday Name'] = opsd_daily.index.day_name()
# Display a random sampling of 5 rows
opsd_daily.sample(5, random_state=0)
# Out:
#             Consumption    Wind    Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2008-08-23     1152.011     NaN      NaN         NaN  2008      8     Saturday
# 2013-08-08     1291.984  79.666   93.371     173.037  2013      8     Thursday
# 2009-08-27     1281.057     NaN      NaN         NaN  2009      8     Thursday
# 2015-10-02     1391.050  81.229  160.641     241.870  2015     10       Friday
# 2009-06-02     1201.522     NaN      NaN         NaN  2009      6      Tuesday

# %%
# Access data by date index
opsd_daily.loc['2013-08-08']
opsd_daily.loc['2013-08-08':'2013-08-10']
# Out:
#             Consumption    Wind    Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2013-08-08     1291.984  79.666   93.371     173.037  2013      8     Thursday
# 2013-08-09     1254.462  19.564   89.341     108.905  2013      8       Friday
# 2013-08-10     1088.538  81.408  144.125     225.533  2013      8     Saturday

# %%
# Partial string match indexing
opsd_daily.loc['2012-12']
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2012-12-01     1243.897   97.660  18.084     115.744  2012     12     Saturday
# 2012-12-02     1151.585   63.020   8.789      71.809  2012     12       Sunday
# 2012-12-03     1484.956  142.974  13.421     156.395  2012     12       Monday
# 2012-12-04     1469.941  257.595   9.724     267.319  2012     12      Tuesday
# 2012-12-05     1507.404  111.197  15.454     126.651  2012     12    Wednesday
# 2012-12-06     1502.183  170.551  13.026     183.577  2012     12     Thursday
# 2012-12-07     1519.663  124.988  12.946     137.934  2012     12       Friday
# 2012-12-08     1301.548   42.738  15.514      58.252  2012     12     Saturday
# 2012-12-09     1156.396  302.536   5.943     308.479  2012     12       Sunday
# 2012-12-10     1515.692  198.226   4.487     202.713  2012     12       Monday
# 2012-12-11     1520.748  135.903   5.715     141.618  2012     12      Tuesday
# ...

# %%
### Data visualization

# Display figures inline in Jupyter notebook
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})
opsd_daily['Consumption'].plot(linewidth=0.5);

# %%
#Plot per column, scatter

cols_plot = ['Consumption', 'Solar', 'Wind']
axes = opsd_daily[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily Totals (GWh)')

# %%
#Plot single year. Investigate patterns
ax = opsd_daily.loc['2017', 'Consumption'].plot()
ax.set_ylabel('Daily Consumption (GWh)');

# %%
# Investigate two months
ax = opsd_daily.loc['2017-01':'2017-02', 'Consumption'].plot(marker='o', linestyle='-')
ax.set_ylabel('Daily Consumption (GWh)');
